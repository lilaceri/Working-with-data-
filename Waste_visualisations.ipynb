# %% [markdown]
# <a href="https://colab.research.google.com/github/lilaceri/Working-with-data-/blob/main/Waste_visualisations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df = pd.read_csv("http://data.defra.gov.uk/Waste/Table1_1_Waste_Households_UK_country_2010_19.csv")
# Out:
#     Year                      Measure      UK England   NI Scotland  Wales
# 0   2010  Arisings  (thousand tonnes)  26,954  22,131  829    2,649  1,344
# 1   2010        Recycled (excl. IBAm)  10,878   9,112  314      861    591
# 2   2011  Arisings  (thousand tonnes)  26,792  22,170  810    2,482  1,329
# 3   2011        Recycled (excl. IBAm)  11,492   9,596  324      921    651
# 4   2012  Arisings  (thousand tonnes)  26,428  21,956  783    2,383  1,306
# 5   2012        Recycled (excl. IBAm)  11,594   9,684  319      911    681
# 6   2013  Arisings  (thousand tonnes)  25,929  21,564  781    2,310  1,274
# 7   2013        Recycled (excl. IBAm)  11,428   9,523  324      916    665
# 8   2014  Arisings  (thousand tonnes)  26,795  22,355  806    2,349  1,285
# 9   2014        Recycled (excl. IBAm)  12,015  10,025  344      962    685
# 10  2015  Arisings  (thousand tonnes)  26,675  22,225  818    2,354  1,278
# ...
