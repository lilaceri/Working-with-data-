# %% [markdown]
# <a href="https://colab.research.google.com/github/lilaceri/Working-with-data-/blob/main/Copy_of_Interrogating_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interrogating the dataframe
# ---
#
# We use pandas to create dataframes from data sets in files or online tables.
#
# Once we have the dataframe we might want to:
# *   display a subset of rows
# *   *   we can do this using df.head(), df.tail() or df.iloc[index]
# *   display a subset of columns
# *   *   we can do this using the column name as the key, e.g.
# `                df['rain (mm)']`
# *   *   we can display more than one column, simply by listing the columns in the square brackets, e.g.
# `                df[['rain (mm)', 'tmin (degC)', 'sun (hours)']]`
# *   *   and can dislay a subset of rows for a subset of columns, e.g.
#  `               df[['rain (mm)', 'tmax (degC)']].head(10)`

# %% [markdown]
# ### Exercise 1 - get the data, look at first 10 records
# ---
#
#
# 1.  Import the pandas library with the alias pd
# 2.  Read the sheet with the name "Industry Migration" from the Excel file from this link: https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true  (*Hint:  use pd.read_excel(url, sheet_name="Industry Migration") with the above url.*)
# 3.  display the first 10 rows of the data

# %%
import pandas as pd 
url = "https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true "
df = pd.read_excel(url, sheet_name="Industry Migration")
first_ten = df.head(10)
first_ten
# Out:
#   country_code          country_name  ... net_per_10K_2018 net_per_10K_2019
# 0           ae  United Arab Emirates  ...            68.51            49.55
# 1           ae  United Arab Emirates  ...           149.57           182.22
# 2           ae  United Arab Emirates  ...           409.18           407.41
# 3           ae  United Arab Emirates  ...           236.69           188.07
# 4           ae  United Arab Emirates  ...           852.39           519.40
# 5           ae  United Arab Emirates  ...           283.59           281.91
# 6           ae  United Arab Emirates  ...           356.56           147.83
# 7           ae  United Arab Emirates  ...           475.62           255.21
# 8           ae  United Arab Emirates  ...           574.60           406.03
# 9           ae  United Arab Emirates  ...           205.78           513.23
#
# [10 rows x 13 columns]

# %% [markdown]
# ### Exercise 2 - display just two columns
#
# Display the first 50 records focusing on the industries where migration is happening in each country (show just country_name and industry_name).

# %%
first_50 = df[["country_name", "industry_name"]].head(50)
first_50
# Out:
#             country_name              industry_name
# 0   United Arab Emirates            Defense & Space
# 1   United Arab Emirates          Computer Hardware
# 2   United Arab Emirates          Computer Software
# 3   United Arab Emirates        Computer Networking
# 4   United Arab Emirates                   Internet
# 5   United Arab Emirates         Telecommunications
# 6   United Arab Emirates               Law Practice
# 7   United Arab Emirates             Legal Services
# 8   United Arab Emirates      Management Consulting
# 9   United Arab Emirates              Biotechnology
# 10  United Arab Emirates           Medical Practice
# 11  United Arab Emirates     Hospital & Health Care
# 12  United Arab Emirates            Pharmaceuticals
# 13  United Arab Emirates             Medical Device
# 14  United Arab Emirates                  Cosmetics
# 15  United Arab Emirates          Apparel & Fashion
# 16  United Arab Emirates             Sporting Goods
# 17  United Arab Emirates                    Tobacco
# 18  United Arab Emirates               Supermarkets
# 19  United Arab Emirates            Food Production
# 20  United Arab Emirates       Consumer Electronics
# 21  United Arab Emirates             Consumer Goods
# 22  United Arab Emirates                  Furniture
# 23  United Arab Emirates                     Retail
# 24  United Arab Emirates              Entertainment
# 25  United Arab Emirates  Leisure, Travel & Tourism
# 26  United Arab Emirates                Hospitality
# 27  United Arab Emirates                Restaurants
# 28  United Arab Emirates                     Sports
# 29  United Arab Emirates           Food & Beverages
# 30  United Arab Emirates     Motion Pictures & Film
# 31  United Arab Emirates            Broadcast Media
# 32  United Arab Emirates                    Banking
# 33  United Arab Emirates                  Insurance
# 34  United Arab Emirates         Financial Services
# 35  United Arab Emirates                Real Estate
# 36  United Arab Emirates         Investment Banking
# 37  United Arab Emirates      Investment Management
# 38  United Arab Emirates                 Accounting
# 39  United Arab Emirates               Construction
# 40  United Arab Emirates         Building Materials
# 41  United Arab Emirates    Architecture & Planning
# 42  United Arab Emirates          Civil Engineering
# 43  United Arab Emirates       Aviation & Aerospace
# 44  United Arab Emirates                 Automotive
# 45  United Arab Emirates                  Chemicals
# 46  United Arab Emirates                  Machinery
# 47  United Arab Emirates            Mining & Metals
# 48  United Arab Emirates               Oil & Energy
# 49  United Arab Emirates               Shipbuilding

# %% [markdown]
# ### Exercise 3 - yearly migration
#
# *   display the middle 20 records, showing the country_name and the migration for each of the years 2015 to 2019.
# ---

# %%
yearly_migration = df[["country_name", "net_per_10K_2015",	"net_per_10K_2016",	"net_per_10K_2017",	'net_per_10K_2018',	'net_per_10K_2019']].iloc[len(df)//2:(len(df)//2)+20]
yearly_migration
# Out:
#      country_name  net_per_10K_2015  ...  net_per_10K_2018  net_per_10K_2019
# 2647        India            -31.78  ...            -66.87            -95.41
# 2648        India             24.01  ...            -29.43            -63.83
# 2649        India            -17.74  ...            -63.91            -50.87
# 2650        India            -26.23  ...            -40.06            -55.07
# 2651        India            -75.42  ...            -95.02           -106.56
# 2652        India            -40.41  ...            -70.58           -142.21
# 2653         Iraq            290.14  ...            396.23            318.73
# 2654         Iraq             23.68  ...            -87.85            -38.84
# 2655         Iraq           -138.81  ...           -109.23              0.00
# 2656         Iraq           -718.56  ...           -456.94             95.72
# 2657         Iraq            332.56  ...           -415.17             50.52
# 2658         Iraq              0.00  ...              0.00            253.34
# 2659         Iraq            154.70  ...            100.40            132.11
# 2660         Iraq            174.18  ...             55.44             73.64
# 2661         Iraq              0.00  ...             -5.91             82.91
# 2662         Iraq            -46.82  ...           -132.78            -29.89
# 2663         Iraq            434.67  ...             95.98            245.83
# 2664         Iraq            137.84  ...           -140.85             95.04
# 2665         Iraq            590.52  ...             79.12             25.88
# 2666         Iraq            -25.80  ...            -43.80            159.59
#
# [20 rows x 6 columns]

# %% [markdown]
# ### Exercise 4 - migration to and from
# ---
#
# The Excel file at this link (which you have already opened above): https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true has three data sheets, "Country Migration", "Industry Migration" and "Skills Migration"
#
# Open the data sheet "Country Migration" and display the first 10 records showing the country that migration was to, the country it was from and the net migration for each year from 2015 to 2019

# %%
df_cm = pd.read_excel(url, sheet_name="Country Migration")

df_cm[["base_country_name", "target_country_name", "net_per_10K_2015",	"net_per_10K_2016",	"net_per_10K_2017",	'net_per_10K_2018',	'net_per_10K_2019']].head(10)
# Out:
#       base_country_name target_country_name  ...  net_per_10K_2018  net_per_10K_2019
# 0  United Arab Emirates         Afghanistan  ...             -0.05             -0.02
# 1  United Arab Emirates             Algeria  ...              0.55              0.78
# 2  United Arab Emirates              Angola  ...             -0.02             -0.06
# 3  United Arab Emirates           Argentina  ...              0.01              0.23
# 4  United Arab Emirates             Armenia  ...             -0.01              0.02
# 5  United Arab Emirates           Australia  ...             -4.58             -4.09
# 6  United Arab Emirates             Austria  ...             -0.05             -0.16
# 7  United Arab Emirates          Azerbaijan  ...              0.05              0.04
# 8  United Arab Emirates             Bahrain  ...             -0.07              0.15
# 9  United Arab Emirates          Bangladesh  ...             -0.18             -0.04
#
# [10 rows x 7 columns]

# %% [markdown]
# ### Exercise 5 - unique countries
#
# Using the "Country Migration" sheet, get all the unique country names from where people have migrated (base_country_name) and use a for loop to print a list of the countries.

# %%
base_countries = df_cm["base_country_name"].unique()
def unique_items(items):
  item_list = []
  for item in items:
    item_list.append(item)
  print(item_list)

unique_items(base_countries)
# Out:
# ['United Arab Emirates', 'Afghanistan', 'Albania', 'Armenia', 'Angola', 'Argentina', 'Austria', 'Australia', 'Azerbaijan', 'Bosnia and Herzegovina', 'Bangladesh', 'Belgium', 'Burkina Faso', 'Bulgaria', 'Bahrain', 'Benin', 'Bolivia', 'Brazil', 'Bahamas, The', 'Botswana', 'Belarus', 'Canada', 'Congo, Dem. Rep.', 'Switzerland', "Cote d'Ivoire", 'Chile', 'Cameroon', 'China', 'Colombia', 'Costa Rica', 'Cuba', 'Cyprus', 'Czech Republic', 'Germany', 'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'Estonia', 'Egypt, Arab Rep.', 'Spain', 'Ethiopia', 'Finland', 'Fiji', 'France', 'Gabon', 'United Kingdom', 'Georgia', 'Ghana', 'Greece', 'Guatemala', 'Hong Kong SAR, China', 'Honduras', 'Croatia', 'Haiti', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'India', 'Iraq', 'Iran, Islamic Rep.', 'Iceland', 'Italy', 'Jamaica', 'Jordan', 'Japan', 'Kenya', 'Cambodia', 'Korea, Rep.', 'Kuwait', 'Kazakhstan', 'Lebanon', 'Sri Lanka', 'Lithuania', 'Luxembourg', 'Latvia', 'Libya', 'Morocco', 'Moldova', 'Madagascar', 'Macedonia, FYR', 'Mali', 'Myanmar', 'Mongolia', 'Malta', 'Mauritius', 'Malawi', 'Mexico', 'Malaysia', 'Mozambique', 'Namibia', 'Nigeria', 'Nicaragua', 'Netherlands', 'Norway', 'Nepal', 'New Zealand', 'Oman', 'Panama', 'Peru', 'Papua New Guinea', 'Philippines', 'Pakistan', 'Poland', 'Puerto Rico', 'West Bank and Gaza', 'Portugal', 'Paraguay', 'Qatar', 'Romania', 'Serbia', 'Rwanda', 'Saudi Arabia', 'Sudan', 'Sweden', 'Singapore', 'Slovenia', 'Slovak Republic', 'Senegal', 'El Salvador', 'Syrian Arab Republic', 'Togo', 'Thailand', 'Tunisia', 'Turkey', 'Trinidad and Tobago', 'Taiwan, China', 'Tanzania', 'Ukraine', 'Uganda', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, RB', 'Vietnam', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe']

# %% [markdown]
# ### Exercise 6 - how many countries are migrated to
#
# Using the "Country Migration" sheet again, get all the unique country names to where people have migrated and display the number of unique countries.

# %%
target_countries = df_cm["target_country_name"].unique()
unique_items(target_countries)
def number_countries(countries):
  country_count = len(countries)
  print(country_count)
number_countries(target_countries)
# Out:
# ['Afghanistan', 'Algeria', 'Angola', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Belarus', 'Belgium', 'Brazil', 'Bulgaria', 'Cameroon', 'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Egypt, Arab Rep.', 'Ethiopia', 'Finland', 'France', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Hong Kong SAR, China', 'Hungary', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Italy', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Korea, Rep.', 'Kuwait', 'Lebanon', 'Libya', 'Luxembourg', 'Macedonia, FYR', 'Malaysia', 'Malta', 'Mauritius', 'Mexico', 'Morocco', 'Myanmar', 'Nepal', 'Netherlands', 'New Zealand', 'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Saudi Arabia', 'Serbia', 'Singapore', 'Slovak Republic', 'South Africa', 'Spain', 'Sri Lanka', 'Sudan', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan, China', 'Tanzania', 'Thailand', 'Tunisia', 'Turkey', 'Uganda', 'Ukraine', 'United Kingdom', 'United States', 'Uzbekistan', 'Venezuela, RB', 'Vietnam', 'West Bank and Gaza', 'Yemen, Rep.', 'Zimbabwe', 'United Arab Emirates', 'Namibia', 'Bolivia', 'Costa Rica', 'Dominican Republic', 'Ecuador', 'Israel', 'Panama', 'Paraguay', 'Peru', 'Uruguay', 'Bosnia and Herzegovina', 'Slovenia', 'Cambodia', 'Estonia', 'Fiji', 'Lithuania', 'Mongolia', 'Papua New Guinea', 'Zambia', 'Albania', 'Benin', 'Congo, Dem. Rep.', "Cote d'Ivoire", 'Latvia', 'Senegal', 'Mozambique', 'Bahamas, The', 'Burkina Faso', 'Cuba', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Iceland', 'Jamaica', 'Madagascar', 'Moldova', 'Nicaragua', 'Rwanda', 'Trinidad and Tobago', 'Mali', 'Togo', 'Gabon', 'Puerto Rico', 'Botswana', 'Malawi']
# 140

# %% [markdown]
# ### Exercise 7 - skill sets
# ---
#
#
# Using the "Skill Migration" data sheet, display the following:
# *  the first record
# *  the last 10 records
# *  records from index 500 to index 600
# *  a count of all unique countries
# *  a list of all unique skill group categories
# *  the first 50 skill group names and net migration in 2019

# %%
df_sm = pd.read_excel(url, sheet_name="Skill Migration")

first_sm = df_sm.head(1)
last_10_sm = df_sm.tail(10)
index_500_600_sm = df_sm.iloc[500:601]
ncountrys_sm = df_sm["country_name"].nunique()
skill_catergories = df_sm["skill_group_category"].unique()
df_sm.head(10)
# unique_items(skill_catergories)
skill_50_2019 = df_sm[["skill_group_name", "net_per_10K_2019"]].head(50)
skill_50_2019
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c4039e9eaf1b> in <module>()
# ----> 1 df_sm = pd.read_excel(url, sheet_name="Skill Migration")
#       2
#       3 first_sm = df_sm.head(1)
#       4 last_10_sm = df_sm.tail(10)
#       5 index_500_600_sm = df_sm.iloc[500:601]
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Exercise 8 - total net migration over 5 years
# ---
#
# Using the Country Migration data sheet, display the record at position 10.  Using the column names to access the data in each column, add the five columns containing the net migration data together to calculate the total net migration over the 5 years between 2015 and 2019.

# %%
tenth_cm = df_cm.iloc[9]
tenth_cm
# Out:
# base_country_code                                   ae
# base_country_name                 United Arab Emirates
# base_lat                                       23.4241
# base_long                                      53.8478
# base_country_wb_income                     High Income
# base_country_wb_region      Middle East & North Africa
# target_country_code                                 bd
# target_country_name                         Bangladesh
# target_lat                                      23.685
# target_long                                    90.3563
# target_country_wb_income           Lower Middle Income
# target_country_wb_region                    South Asia
# net_per_10K_2015                                 -0.21
# net_per_10K_2016                                 -0.21
# net_per_10K_2017                                 -0.26
# net_per_10K_2018                                 -0.18
# net_per_10K_2019                                 -0.04
# Name: 9, dtype: object

# %%
def total_mig(sheet):
  total = sheet[["net_per_10K_2015",	"net_per_10K_2016",	"net_per_10K_2017",	'net_per_10K_2018',	'net_per_10K_2019']].sum()
  return total
total_mig(tenth_cm)
# tenth_cm[["net_per_10K_2015",	"net_per_10K_2016",	"net_per_10K_2017",	'net_per_10K_2018',	'net_per_10K_2019']].sum()
# Out:
# -0.8999999999999999

# %% [markdown]
# ### Exercise 9 - formulating a text response
#
# Using the Industry Migration data sheet, display the record at position 100.  Using the column names again to access the data in each column, calculate net migration over the 5 years from 2015 to 2019.
#
# Then print the following message, adding the data where indicated:
#
# The total net migration into `country` of skilled workers for the `industry name` industry, during the years 2015-2019 was `total_net_migration`

# %%
im_100 = df.iloc[99]
total_migration = print(total_mig(im_100))
total_migration
print("The total net migration into ", im_100["country_name"], "of skilled workers for the ", im_100["industry_name"], "industry, during the years 2015-2019 was ", total_mig(im_100))
# Out:
# 1867.48
# The total net migration into  United Arab Emirates of skilled workers for the  Commercial Real Estate industry, during the years 2015-2019 was  1867.48

# %% [markdown]
# ### Exercise 10 - five text responses
#
# Using the Industry Migration data sheet, calculate net migration (rounded to 1 decimal place) over the 5 years from 2015 to 2019 for the records at positions 1 to 5 and print the following message for each, adding the data where indicated:
#
# The total net migration into `country` of skilled workers for the `industry name` industry, during the years 2015-2019 was `total_net_migration`
#
# *Hint: use a for loop to get a record and do each calculation*

# %%
im_first_5 = df.iloc[0:5]
im_first_5

for row in range(len(im_first_5)):
    # total = im_first_5.loc[row][["net_per_10K_2015",	"net_per_10K_2016",	"net_per_10K_2017",	'net_per_10K_2018',	'net_per_10K_2019']].sum()
    total = round(total_mig(im_first_5.iloc[row]),1)
    print("The total net migration into ", im_first_5.iloc[row]["country_name"], "of skilled workers for the ", im_first_5.iloc[row]["industry_name"], "industry, during the years 2015-2019 was ", total)
# Out:
# The total net migration into  United Arab Emirates of skilled workers for the  Defense & Space industry, during the years 2015-2019 was  632.9
# The total net migration into  United Arab Emirates of skilled workers for the  Computer Hardware industry, during the years 2015-2019 was  903.9
# The total net migration into  United Arab Emirates of skilled workers for the  Computer Software industry, during the years 2015-2019 was  3340.6
# The total net migration into  United Arab Emirates of skilled workers for the  Computer Networking industry, during the years 2015-2019 was  1437.6
# The total net migration into  United Arab Emirates of skilled workers for the  Internet industry, during the years 2015-2019 was  5458.2
